# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# importing package
import matplotlib.pyplot as plt
import pandas as pd
  
# create data
df = pd.DataFrame([['Gradient Boosting', 99.94, 99.68, 99.29, 99.48], ['Random Forest', 99.96, 99.78, 99.63, 99.68], ['Logistic Regression', 96.98, 57.48, 85.90, 68.82],
                   ['KNN', 98.87, 86.68, 93.80, 89.92],  ['Decision Tree', 99.96, 99.73, 99.56, 99.69], ['MLP', 96.69, 57.89, 86.60, 59.34], ['AdaBoost', 99.98, 99.85, 99.82, 99.84], ['XGBoost', 99.97, 99.79, 99.75, 99.82], ['LDA', 97.00, 61.21, 82.78, 70.35], ['CART', 99.96, 99.80, 99.58, 99.68]],
                  columns=['Models', 'Accuracy', 'Recall', 'Presicion', 'F1'])
# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Models',
        kind='bar',
        stacked=False,
        title='Evalution Metrics Performance')
# Out:
#                 Models  Accuracy  Recall  Presicion     F1
# 0    Gradient Boosting     99.94   99.68      99.29  99.48
# 1        Random Forest     99.96   99.78      99.63  99.68
# 2  Logistic Regression     96.98   57.48      85.90  68.82
# 3                  KNN     98.87   86.68      93.80  89.92
# 4        Decision Tree     99.96   99.73      99.56  99.69
# 5                  MLP     96.69   57.89      86.60  59.34
# 6             AdaBoost     99.98   99.85      99.82  99.84
# 7              XGBoost     99.97   99.79      99.75  99.82
# 8                  LDA     97.00   61.21      82.78  70.35
# 9                 CART     99.96   99.80      99.58  99.68
# <AxesSubplot:title={'center':'Evalution Metrics Performance'}, xlabel='Models'>
